# %%
import pandas as pd
from pathlib import Path

# %%
split_info_df = pd.read_csv(Path("resources", "subject_info_df.csv"))

# %%
split_info_df
# Out:
#        SUBJECT_ID  ICUSTAY_ID    DBSOURCE CAREUNIT  WARDID ADMISSION_TYPE  \
# 0             268      280836     carevue     MICU      52      EMERGENCY
# 1             269      206613     carevue     MICU      52      EMERGENCY
# 2             270      220345     carevue      CCU      57       ELECTIVE
# 3             272      210407     carevue      CCU      57      EMERGENCY
# 4             273      241507     carevue     MICU      52      EMERGENCY
# ...           ...         ...         ...      ...     ...            ...
# 55825       94944      201233  metavision     CSRU      15      EMERGENCY
# 55826       94950      283653  metavision      CCU       7      EMERGENCY
# 55827       94953      241585  metavision     SICU      57       ELECTIVE
# 55828       94954      202802  metavision     CSRU      15       ELECTIVE
# 55829       94956      275346  metavision    TSICU      14      EMERGENCY
#
#               ADMISSION_LOCATION DISCHARGE_LOCATION INSURANCE LANGUAGE  \
# ...
